# %%
examples = {"key1": "value1", "key2": "value2"}

# %%
examples['key1']
# Out:
# 'value1'

# %%
from box import ConfigBox

# %%
examples = ConfigBox(examples)

# %%
examples.key2
# Out:
# 'value2'

# %%
# Ensure explanations are provided for the code changes in the research.ipynb file.
def get_product(x: int, y: int) -> int:
    """
    This function takes two integers as input and returns their product.
    
    Parameters:
    x (int): The first integer.
    y (int): The second integer.
    
    Returns:
    int: The product of the two integers.
    """
    return x * y

# %%
get_product(3, 4)
# Out:
# 12

# %%
get_product(3, "4")
# Out:
# '444'

# %%
from ensure import ensure_annotations
@ensure_annotations
def get_product(x: int, y: int) -> int:
    """
    This function takes two integers as input and returns their product.
    
    Parameters:
    x (int): The first integer.
    y (int): The second integer.
    
    Returns:
    int: The product of the two integers.
    """
    return x * y

# %%
get_product(3, "4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 get_product(3, "4")
#
# File ~/Simple_MLOPS/venv/lib/python3.12/site-packages/ensure/main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x10fa73e20> does not match annotation type <class 'int'>
